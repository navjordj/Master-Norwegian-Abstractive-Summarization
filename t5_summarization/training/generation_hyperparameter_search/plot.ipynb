# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("hyperparam_search_results.csv")

# %%
df
# Out:
#     Unnamed: 0                                             config    rouge1  \
# 0            0                                                 {}  0.291164
# 1            1  {'max_length': 80, 'num_beams': 6, 'early_stop...  0.314630
# 2            2  {'max_length': 80, 'num_beams': 6, 'early_stop...  0.309773
# 3            3  {'max_length': 80, 'num_beams': 6, 'repetition...  0.314473
# 4            4  {'max_length': 80, 'num_beams': 6, 'repetition...  0.318833
# 5            5  {'max_length': 80, 'num_beams': 6, 'no_repeat_...  0.315607
# 6            6  {'max_length': 80, 'num_beams': 6, 'no_repeat_...  0.325428
# 7            7  {'max_length': 80, 'num_beams': 6, 'no_repeat_...  0.314923
# 8            8  {'max_length': 80, 'do_sample': True, 'top_k': 0}  0.284318
# 9            9  {'max_length': 80, 'do_sample': True, 'top_k':...  0.314913
# 10          10  {'max_length': 80, 'do_sample': True, 'top_k':...  0.289643
# 11          11  {'max_length': 80, 'do_sample': True, 'top_p':...  0.293781
#
#       rouge2    rougeL  rougeLsum  total_time_in_seconds  samples_per_second  \
# 0   0.156262  0.268757   0.268382             145.189996            5.640885
# 1   0.151129  0.277511   0.277378             458.735651            1.785342
# 2   0.146983  0.270912   0.270807             549.326722            1.490916
# 3   0.148597  0.273663   0.273507             531.010548            1.542342
# 4   0.148527  0.275029   0.274537             511.126702            1.602342
# 5   0.147155  0.273302   0.273390             469.177147            1.745609
# 6   0.156785  0.283641   0.283523             466.419473            1.755930
# 7   0.151292  0.277531   0.277418             474.010225            1.727811
# 8   0.103911  0.231142   0.230805             406.753613            2.013504
# 9   0.132903  0.263445   0.263453             364.575429            2.246449
# 10  0.107382  0.237252   0.236857             407.029380            2.012140
# 11  0.114765  0.242843   0.242870             394.614758            2.075442
#
#     latency_in_seconds
# 0             0.177277
# 1             0.560117
# 2             0.670729
# 3             0.648365
# 4             0.624086
# 5             0.572866
# 6             0.569499
# 7             0.578767
# 8             0.496647
# 9             0.445147
# 10            0.496983
# 11            0.481825

# %%
def highlight_max(data, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    #remove % and cast to float
    data = data.replace('%','', regex=True).astype(float)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
df.style.highlight_max(color = 'blue', axis = 0)
# Out:
# <style type="text/css">
# #T_dc25b_row0_col1, #T_dc25b_row0_col7, #T_dc25b_row2_col6, #T_dc25b_row2_col8, #T_dc25b_row6_col2, #T_dc25b_row6_col3, #T_dc25b_row6_col4, #T_dc25b_row6_col5, #T_dc25b_row11_col0 {
#   background-color: blue;
# }
# </style>
# <table id="T_dc25b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc25b_level0_col0" class="col_heading level0 col0" >Unnamed: 0</th>
#       <th id="T_dc25b_level0_col1" class="col_heading level0 col1" >config</th>
#       <th id="T_dc25b_level0_col2" class="col_heading level0 col2" >rouge1</th>
#       <th id="T_dc25b_level0_col3" class="col_heading level0 col3" >rouge2</th>
#       <th id="T_dc25b_level0_col4" class="col_heading level0 col4" >rougeL</th>
#       <th id="T_dc25b_level0_col5" class="col_heading level0 col5" >rougeLsum</th>
#       <th id="T_dc25b_level0_col6" class="col_heading level0 col6" >total_time_in_seconds</th>
#       <th id="T_dc25b_level0_col7" class="col_heading level0 col7" >samples_per_second</th>
#       <th id="T_dc25b_level0_col8" class="col_heading level0 col8" >latency_in_seconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc25b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc25b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_dc25b_row0_col1" class="data row0 col1" >{}</td>
#       <td id="T_dc25b_row0_col2" class="data row0 col2" >0.291164</td>
#       <td id="T_dc25b_row0_col3" class="data row0 col3" >0.156262</td>
#       <td id="T_dc25b_row0_col4" class="data row0 col4" >0.268757</td>
#       <td id="T_dc25b_row0_col5" class="data row0 col5" >0.268382</td>
#       <td id="T_dc25b_row0_col6" class="data row0 col6" >145.189996</td>
#       <td id="T_dc25b_row0_col7" class="data row0 col7" >5.640885</td>
#       <td id="T_dc25b_row0_col8" class="data row0 col8" >0.177277</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc25b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_dc25b_row1_col1" class="data row1 col1" >{'max_length': 80, 'num_beams': 6, 'early_stopping': True}</td>
#       <td id="T_dc25b_row1_col2" class="data row1 col2" >0.314630</td>
#       <td id="T_dc25b_row1_col3" class="data row1 col3" >0.151129</td>
#       <td id="T_dc25b_row1_col4" class="data row1 col4" >0.277511</td>
#       <td id="T_dc25b_row1_col5" class="data row1 col5" >0.277378</td>
#       <td id="T_dc25b_row1_col6" class="data row1 col6" >458.735651</td>
#       <td id="T_dc25b_row1_col7" class="data row1 col7" >1.785342</td>
#       <td id="T_dc25b_row1_col8" class="data row1 col8" >0.560117</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc25b_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_dc25b_row2_col1" class="data row2 col1" >{'max_length': 80, 'num_beams': 6, 'early_stopping': False}</td>
#       <td id="T_dc25b_row2_col2" class="data row2 col2" >0.309773</td>
#       <td id="T_dc25b_row2_col3" class="data row2 col3" >0.146983</td>
#       <td id="T_dc25b_row2_col4" class="data row2 col4" >0.270912</td>
#       <td id="T_dc25b_row2_col5" class="data row2 col5" >0.270807</td>
#       <td id="T_dc25b_row2_col6" class="data row2 col6" >549.326722</td>
#       <td id="T_dc25b_row2_col7" class="data row2 col7" >1.490916</td>
#       <td id="T_dc25b_row2_col8" class="data row2 col8" >0.670729</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc25b_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_dc25b_row3_col1" class="data row3 col1" >{'max_length': 80, 'num_beams': 6, 'repetition_penalty': 1.2}</td>
#       <td id="T_dc25b_row3_col2" class="data row3 col2" >0.314473</td>
#       <td id="T_dc25b_row3_col3" class="data row3 col3" >0.148597</td>
#       <td id="T_dc25b_row3_col4" class="data row3 col4" >0.273663</td>
#       <td id="T_dc25b_row3_col5" class="data row3 col5" >0.273507</td>
#       <td id="T_dc25b_row3_col6" class="data row3 col6" >531.010548</td>
#       <td id="T_dc25b_row3_col7" class="data row3 col7" >1.542342</td>
#       <td id="T_dc25b_row3_col8" class="data row3 col8" >0.648365</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc25b_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_dc25b_row4_col1" class="data row4 col1" >{'max_length': 80, 'num_beams': 6, 'repetition_penalty': 2.0}</td>
#       <td id="T_dc25b_row4_col2" class="data row4 col2" >0.318833</td>
#       <td id="T_dc25b_row4_col3" class="data row4 col3" >0.148527</td>
#       <td id="T_dc25b_row4_col4" class="data row4 col4" >0.275029</td>
#       <td id="T_dc25b_row4_col5" class="data row4 col5" >0.274537</td>
#       <td id="T_dc25b_row4_col6" class="data row4 col6" >511.126702</td>
#       <td id="T_dc25b_row4_col7" class="data row4 col7" >1.602342</td>
#       <td id="T_dc25b_row4_col8" class="data row4 col8" >0.624086</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dc25b_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_dc25b_row5_col1" class="data row5 col1" >{'max_length': 80, 'num_beams': 6, 'no_repeat_ngram_size': 2, 'early_stopping': True}</td>
#       <td id="T_dc25b_row5_col2" class="data row5 col2" >0.315607</td>
#       <td id="T_dc25b_row5_col3" class="data row5 col3" >0.147155</td>
#       <td id="T_dc25b_row5_col4" class="data row5 col4" >0.273302</td>
#       <td id="T_dc25b_row5_col5" class="data row5 col5" >0.273390</td>
#       <td id="T_dc25b_row5_col6" class="data row5 col6" >469.177147</td>
#       <td id="T_dc25b_row5_col7" class="data row5 col7" >1.745609</td>
#       <td id="T_dc25b_row5_col8" class="data row5 col8" >0.572866</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dc25b_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_dc25b_row6_col1" class="data row6 col1" >{'max_length': 80, 'num_beams': 6, 'no_repeat_ngram_size': 4, 'early_stopping': True}</td>
#       <td id="T_dc25b_row6_col2" class="data row6 col2" >0.325428</td>
#       <td id="T_dc25b_row6_col3" class="data row6 col3" >0.156785</td>
#       <td id="T_dc25b_row6_col4" class="data row6 col4" >0.283641</td>
#       <td id="T_dc25b_row6_col5" class="data row6 col5" >0.283523</td>
#       <td id="T_dc25b_row6_col6" class="data row6 col6" >466.419473</td>
#       <td id="T_dc25b_row6_col7" class="data row6 col7" >1.755930</td>
#       <td id="T_dc25b_row6_col8" class="data row6 col8" >0.569499</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dc25b_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_dc25b_row7_col1" class="data row7 col1" >{'max_length': 80, 'num_beams': 6, 'no_repeat_ngram_size': 24, 'early_stopping': True}</td>
#       <td id="T_dc25b_row7_col2" class="data row7 col2" >0.314923</td>
#       <td id="T_dc25b_row7_col3" class="data row7 col3" >0.151292</td>
#       <td id="T_dc25b_row7_col4" class="data row7 col4" >0.277531</td>
#       <td id="T_dc25b_row7_col5" class="data row7 col5" >0.277418</td>
#       <td id="T_dc25b_row7_col6" class="data row7 col6" >474.010225</td>
#       <td id="T_dc25b_row7_col7" class="data row7 col7" >1.727811</td>
#       <td id="T_dc25b_row7_col8" class="data row7 col8" >0.578767</td>
#     </tr>
#     <tr>
#       <th id="T_dc25b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dc25b_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_dc25b_row8_col1" class="data row8 col1" >{'max_length': 80, 'do_sample': True, 'top_k': 0}</td>
#       <td id="T_dc25b_row8_col2" class="data row8 col2" >0.284318</td>
#       <td id="T_dc25b_row8_col3" class="data row8 col3" >0.103911</td>
#       <td id="T_dc25b_row8_col4" class="data row8 col4" >0.231142</td>
#       <td id="T_dc25b_row8_col5" class="data row8 col5" >0.230805</td>
#       <td id="T_dc25b_row8_col6" class="data row8 col6" >406.753613</td>

# %%
highlight_max(df.drop("config"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jorgen\Documents\summarization_master\t5_summarization\training\generation_hyperparameter_search\plot.ipynb Cell 5 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jorgen/Documents/summarization_master/t5_summarization/training/generation_hyperparameter_search/plot.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> highlight_max(df.drop("config"))
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\core\frame.py:5388, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5240 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5241 def drop(  # type: ignore[override]
#    5242     self,
#    (...)
#    5249     errors: IgnoreRaise = "raise",
#    5250 ) -> DataFrame | None:
#    5251     """
#    5252     Drop specified labels from rows or columns.
#    5253
#    (...)
#    5386             weight  1.0     0.8
#    5387     """
# -> 5388     return super().drop(
#    5389         labels=labels,
#    5390         axis=axis,
#    5391         index=index,
#    5392         columns=columns,
#    5393         level=level,
#    5394         inplace=inplace,
#    5395         errors=errors,
#    5396     )
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\jorgen\miniconda3\lib\site-packages\pandas\core\indexes\base.py:6975, in Index.drop(self, labels, errors)
#    6973 if mask.any():
#    6974     if errors != "ignore":
# -> 6975         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6976     indexer = indexer[~mask]
#    6977 return self.delete(indexer)
#
# KeyError: "['config'] not found in axis"
